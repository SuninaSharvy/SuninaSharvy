# %%
# Visualising Predicted Label Class using Matplot lib & compare with the original extracted label earlier
import matplotlib.pyplot as plt

labels_names = {1: 'Real',0: 'Fake'}

import matplotlib.pyplot as plt

plt.figure(figsize=(12, 12))
for images, labels in test_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow((images[i]*255).numpy().astype(np.uint8))
    plt.title(f'Img: {test_class_names[test_labels[i]]} | Pred: {labels_names[predicted_class[i][0]]} | Conf: {predicted_img_class[i]}%')
    plt.axis("off")
